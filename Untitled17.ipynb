# %%
import pandas as pd

# %%
data = pd.read_csv('fil-t3.csv')

# %%
data
# Out:
#                                       Unnamed: 0  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                   نهاية الفترة
# 6                                  End of Period
# 7         النصف الأول عام 2013م\nFirst half 2013
# 8       النصف الثاني عام 2013م\nSecond half 2013
# 9         النصف الأول عام 2014م\nFirst half 2014
# 10      النصف الثاني عام 2014م\nSecond half 2014
# 11       النصف الأول عام  2015م\nFirst half 2015
# 12   الربع الثالث عام  2015م\nThird quarter 2015
# 13  الربع الرابع عام  2015م\nFourth quarter 2015
# 14    الربع الأول عام  2016م\nFirst quarter 2016
# 15  الربع الثاني عام  2016م\nSecond quarter 2016
# 16   الربع الثالث عام  2016م\nThird quarter 2016
# 17  الربع الرابع عام  2016م\nFourth quarter 2016
# ...

# %%
data.drop([2,3,4,5,6,7])
# Out:
#                                       Unnamed: 0     Unnamed: 1  \
# 0                                            NaN            NaN
# 1                                            NaN            NaN
# 8       النصف الثاني عام 2013م\nSecond half 2013        11536.9
# 9         النصف الأول عام 2014م\nFirst half 2014       13337.08
# 10      النصف الثاني عام 2014م\nSecond half 2014       13667.79
# 11       النصف الأول عام  2015م\nFirst half 2015       13771.24
# 12   الربع الثالث عام  2015م\nThird quarter 2015          22943
# 13  الربع الرابع عام  2015م\nFourth quarter 2015       23499.24
# 14    الربع الأول عام  2016م\nFirst quarter 2016  25845.3961622
# 15  الربع الثاني عام  2016م\nSecond quarter 2016  26234.5179952
# 16   الربع الثالث عام  2016م\nThird quarter 2016       27417.46
# 17  الربع الرابع عام  2016م\nFourth quarter 2016       62300.49
# 18    الربع الأول عام  2017م\nFirst quarter 2017  62166.0207513
# 19  الربع الثاني عام  2017م\nSecond quarter 2017  77137.4548211
# ...

# %%
data.dropna(subset=["Unnamed: 6"], axis=0, inplace = True)

# %%
data
# Out:
#                                       Unnamed: 0     Unnamed: 1  \
# 5                                   نهاية الفترة           أسهم
# 6                                  End of Period       Equities
# 7         النصف الأول عام 2013م\nFirst half 2013       10865.07
# 8       النصف الثاني عام 2013م\nSecond half 2013        11536.9
# 9         النصف الأول عام 2014م\nFirst half 2014       13337.08
# 10      النصف الثاني عام 2014م\nSecond half 2014       13667.79
# 11       النصف الأول عام  2015م\nFirst half 2015       13771.24
# 12   الربع الثالث عام  2015م\nThird quarter 2015          22943
# 13  الربع الرابع عام  2015م\nFourth quarter 2015       23499.24
# 14    الربع الأول عام  2016م\nFirst quarter 2016  25845.3961622
# 15  الربع الثاني عام  2016م\nSecond quarter 2016  26234.5179952
# 16   الربع الثالث عام  2016م\nThird quarter 2016       27417.46
# 17  الربع الرابع عام  2016م\nFourth quarter 2016       62300.49
# 18    الربع الأول عام  2017م\nFirst quarter 2017  62166.0207513
# ...
